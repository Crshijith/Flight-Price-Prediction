# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
business = pd.read_csv('business.csv')
economy = pd.read_csv('economy.csv')

# %%
business['class'] = "business"
economy['class'] = 'economy'

# %%
df = pd.concat([economy,business], ignore_index=True)

# %%
df.head()
# Out:
#          date   airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  SpiceJet      SG      8709    18:55  Delhi    02h 10m
# 1  11-02-2022  SpiceJet      SG      8157    06:20  Delhi    02h 20m
# 2  11-02-2022   AirAsia      I5       764    04:25  Delhi    02h 10m
# 3  11-02-2022   Vistara      UK       995    10:20  Delhi    02h 15m
# 4  11-02-2022   Vistara      UK       963    08:50  Delhi    02h 20m
#
#         stop arr_time      to  price    class
# 0  non-stop     21:05  Mumbai  5,953  economy
# 1  non-stop     08:40  Mumbai  5,953  economy
# 2  non-stop     06:35  Mumbai  5,956  economy
# 3  non-stop     12:35  Mumbai  5,955  economy
# 4  non-stop     11:10  Mumbai  5,955  economy

# %%
df.ch_code.unique()
# Out:
# array(['SG', 'I5', 'UK', 'G8', '6E', 'AI', '2T', 'S5'], dtype=object)

# %%
df.num_code.unique()
# Out:
# array([8709, 8157,  764, ..., 7127, 7259,  433], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300261 entries, 0 to 300260
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        300261 non-null  object
#  1   airline     300261 non-null  object
#  2   ch_code     300261 non-null  object
#  3   num_code    300261 non-null  int64
#  4   dep_time    300261 non-null  object
#  5   from        300261 non-null  object
#  6   time_taken  300261 non-null  object
#  7   stop        300261 non-null  object
#  8   arr_time    300261 non-null  object
#  9   to          300261 non-null  object
#  10  price       300261 non-null  object
#  11  class       300261 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 27.5+ MB

# %%
def stopsfind(stops):  
    stops = stops.replace('Via','').split()
    if stops[0] == "1-stop":
            stops[0] = "one"
    elif stops[0] == "non-stop":
            stops[0] = "zero"
    else:
            stops[0] = "two_or_more"
    if len(stops) == 1:
        return pd.Series([stops[0],"NAN"])
    else:
        return pd.Series([stops[0],stops[1]])

# %%
df[['stops','stops_via']] = df['stop'].apply(stopsfind)

# %%
df['price'] = df['price'].apply(lambda x: int(x.replace(',','')) )

# %%
def codemake(x,y):
    return x + "-" + str(y)

# %%
df['flight_code']=df[['ch_code','num_code']].apply(lambda x: codemake(*x),axis=1)

# %%
df.drop(['ch_code','num_code','stop'],axis=1,inplace=True)

# %%
df.date = df.date.str.split('-')

# %%
df['day_of_journey'] = df.date.str[0]
df['month_of_journey'] = df.date.str[1]

# %%
df.drop(['date'],axis=1,inplace=True)

# %%
df.dep_time = df.dep_time.str.split(':')

# %%
df['dep_hour'] = df.dep_time.str[0]
df['dep_min'] = df.dep_time.str[1]

# %%
df.drop(['dep_time'],axis=1,inplace=True)

# %%
df.arr_time = df.arr_time.str.split(':')

# %%
df['arr_hour'] = df.arr_time.str[0]
df['arr_min'] = df.arr_time.str[1]

# %%
df.drop(['arr_time'],axis=1,inplace=True)

# %%
def time_min(timing):
    timing = timing.replace('h','').replace('m','')
    
    if len(timing.split())==1:
        timing = timing.split('.')
    else:
        timing = timing.split()
        
    timing = int(timing[0])*60 + int(timing[1])

    return timing

# %%
df['duration_in_min']=df['time_taken'].apply(time_min)

# %%
df.drop(['time_taken'],axis=1,inplace=True)

# %%
df[df.duplicated()].head()
# Out:
#         airline   from      to  price    class stops stops_via flight_code  \
# 563   Air India  Delhi  Mumbai  12150  economy   one       NAN      AI-807
# 6181  Air India  Delhi  Mumbai   4780  economy   one       NAN      AI-475
#
#      day_of_journey month_of_journey dep_hour dep_min arr_hour arr_min  \
# 563              14               02       17      20       08      35
# 6181             13               03       13      00       13      35
#
#       duration_in_min
# 563               915
# 6181             1475

# %%
df.drop_duplicates(keep='first',inplace=True)
df.head()
# Out:
#     airline   from      to  price    class stops stops_via flight_code  \
# 0  SpiceJet  Delhi  Mumbai   5953  economy  zero       NAN     SG-8709
# 1  SpiceJet  Delhi  Mumbai   5953  economy  zero       NAN     SG-8157
# 2   AirAsia  Delhi  Mumbai   5956  economy  zero       NAN      I5-764
# 3   Vistara  Delhi  Mumbai   5955  economy  zero       NAN      UK-995
# 4   Vistara  Delhi  Mumbai   5955  economy  zero       NAN      UK-963
#
#   day_of_journey month_of_journey dep_hour dep_min arr_hour arr_min  \
# 0             11               02       18      55       21      05
# 1             11               02       06      20       08      40
# 2             11               02       04      25       06      35
# 3             11               02       10      20       12      35
# 4             11               02       08      50       11      10
#
#    duration_in_min
# 0              130
# 1              140
# 2              130
# 3              135
# 4              140

# %%
df.dep_hour =  df.dep_hour.astype('int64')

# %%
df.arr_hour =  df.arr_hour.astype('int64')

# %%
def deptime(tmm):
    if tmm >= 4 and tmm <= 8:
        day = 'Early Morning'
    elif tmm > 8 and tmm <12:
        day = 'Morning'
    elif tmm >= 12 and tmm < 16:
        day = 'Afternoon'
    elif tmm >= 16 and tmm < 20:
        day = 'Evening'
    elif tmm >= 20 and tmm < 24 :
        day = 'Night'
    else:
        day = 'Late Night'
    return day

# %%
df['dep_time'] = df['dep_hour'].apply(deptime)

# %%
df['arr_time'] = df['arr_hour'].apply(deptime)

# %%
df.head()
# Out:
#     airline   from      to  price    class stops stops_via flight_code  \
# 0  SpiceJet  Delhi  Mumbai   5953  economy  zero       NAN     SG-8709
# 1  SpiceJet  Delhi  Mumbai   5953  economy  zero       NAN     SG-8157
# 2   AirAsia  Delhi  Mumbai   5956  economy  zero       NAN      I5-764
# 3   Vistara  Delhi  Mumbai   5955  economy  zero       NAN      UK-995
# 4   Vistara  Delhi  Mumbai   5955  economy  zero       NAN      UK-963
#
#   day_of_journey month_of_journey  dep_hour dep_min  arr_hour arr_min  \
# 0             11               02        18      55        21      05
# 1             11               02         6      20         8      40
# 2             11               02         4      25         6      35
# 3             11               02        10      20        12      35
# 4             11               02         8      50        11      10
#
#    duration_in_min       dep_time       arr_time
# 0              130        Evening          Night
# 1              140  Early Morning  Early Morning
# 2              130  Early Morning  Early Morning
# 3              135        Morning      Afternoon
# 4              140  Early Morning        Morning

# %%
df.drop(['dep_hour','dep_min','arr_hour','arr_min'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     airline   from      to  price    class stops stops_via flight_code  \
# 0  SpiceJet  Delhi  Mumbai   5953  economy  zero       NAN     SG-8709
# 1  SpiceJet  Delhi  Mumbai   5953  economy  zero       NAN     SG-8157
# 2   AirAsia  Delhi  Mumbai   5956  economy  zero       NAN      I5-764
# 3   Vistara  Delhi  Mumbai   5955  economy  zero       NAN      UK-995
# 4   Vistara  Delhi  Mumbai   5955  economy  zero       NAN      UK-963
#
#   day_of_journey month_of_journey  duration_in_min       dep_time  \
# 0             11               02              130        Evening
# 1             11               02              140  Early Morning
# 2             11               02              130  Early Morning
# 3             11               02              135        Morning
# 4             11               02              140  Early Morning
#
#         arr_time
# 0          Night
# 1  Early Morning
# 2  Early Morning
# 3      Afternoon
# 4        Morning

# %%
df.month_of_journey =  df.month_of_journey.astype('int64')

# %%
def month(m):
    if m == 2:
        month = 'February'
    elif m ==3:
        month = 'March'
    else:
        month = 'Nan'
    return month

# %%
df['month'] = df['month_of_journey'].apply(month)

# %%
df.head()
# Out:
#     airline   from      to  price    class stops stops_via flight_code  \
# 0  SpiceJet  Delhi  Mumbai   5953  economy  zero       NAN     SG-8709
# 1  SpiceJet  Delhi  Mumbai   5953  economy  zero       NAN     SG-8157
# 2   AirAsia  Delhi  Mumbai   5956  economy  zero       NAN      I5-764
# 3   Vistara  Delhi  Mumbai   5955  economy  zero       NAN      UK-995
# 4   Vistara  Delhi  Mumbai   5955  economy  zero       NAN      UK-963
#
#   day_of_journey  month_of_journey  duration_in_min       dep_time  \
# 0             11                 2              130        Evening
# 1             11                 2              140  Early Morning
# 2             11                 2              130  Early Morning
# 3             11                 2              135        Morning
# 4             11                 2              140  Early Morning
#
#         arr_time     month
# 0          Night  February
# 1  Early Morning  February
# 2  Early Morning  February
# 3      Afternoon  February
# 4        Morning  February

# %%
df.day_of_journey =  df.day_of_journey.astype('int64')

# %%
def days(d):
    if d == 1 or d == 8 or d == 15 or d == 22:
        day = 'Tuesday'
    elif d ==2 or d == 9 or d == 16 or d == 23:
        day = 'Wednesday'
    elif d==3 or d == 10 or d == 17 or d == 24:
        day = 'Thursday'
    elif d == 4 or d==11 or d == 18 or d == 25:
        day = 'Friday'
    elif d == 5 or d == 12 or d == 19 or d == 26:
        day = 'Saturday'
    elif d == 6 or d == 13 or d == 20 or d == 27:
        day = 'Sunday'
    elif d == 7 or d == 14 or d == 21 or d == 28:
        day = 'Monday'
    elif d == 29:
        day = 'Tuesday'
    elif d == 30:
        day = 'Wednesday'
    elif d == 31:
        day = 'Thursday'
    else:
        day = 'Nan'
        
    return day

# %%
df['day'] = df['day_of_journey'].apply(days)

# %%
df.head()
# Out:
#     airline   from      to  price    class stops stops_via flight_code  \
# 0  SpiceJet  Delhi  Mumbai   5953  economy  zero       NAN     SG-8709
# 1  SpiceJet  Delhi  Mumbai   5953  economy  zero       NAN     SG-8157
# 2   AirAsia  Delhi  Mumbai   5956  economy  zero       NAN      I5-764
# 3   Vistara  Delhi  Mumbai   5955  economy  zero       NAN      UK-995
# 4   Vistara  Delhi  Mumbai   5955  economy  zero       NAN      UK-963
#
#    day_of_journey  month_of_journey  duration_in_min       dep_time  \
# 0              11                 2              130        Evening
# 1              11                 2              140  Early Morning
# 2              11                 2              130  Early Morning
# 3              11                 2              135        Morning
# 4              11                 2              140  Early Morning
#
#         arr_time     month     day
# 0          Night  February  Friday
# 1  Early Morning  February  Friday
# 2  Early Morning  February  Friday
# 3      Afternoon  February  Friday
# 4        Morning  February  Friday

# %%
df.day.unique()
# Out:
# array(['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday',
#        'Thursday'], dtype=object)

# %%
df.drop(['day_of_journey','month_of_journey'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     airline   from      to  price    class stops stops_via flight_code  \
# 0  SpiceJet  Delhi  Mumbai   5953  economy  zero       NAN     SG-8709
# 1  SpiceJet  Delhi  Mumbai   5953  economy  zero       NAN     SG-8157
# 2   AirAsia  Delhi  Mumbai   5956  economy  zero       NAN      I5-764
# 3   Vistara  Delhi  Mumbai   5955  economy  zero       NAN      UK-995
# 4   Vistara  Delhi  Mumbai   5955  economy  zero       NAN      UK-963
#
#    duration_in_min       dep_time       arr_time     month     day
# 0              130        Evening          Night  February  Friday
# 1              140  Early Morning  Early Morning  February  Friday
# 2              130  Early Morning  Early Morning  February  Friday
# 3              135        Morning      Afternoon  February  Friday
# 4              140  Early Morning        Morning  February  Friday

# %%
df.drop(['flight_code'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     airline   from      to  price    class stops stops_via  duration_in_min  \
# 0  SpiceJet  Delhi  Mumbai   5953  economy  zero       NAN              130
# 1  SpiceJet  Delhi  Mumbai   5953  economy  zero       NAN              140
# 2   AirAsia  Delhi  Mumbai   5956  economy  zero       NAN              130
# 3   Vistara  Delhi  Mumbai   5955  economy  zero       NAN              135
# 4   Vistara  Delhi  Mumbai   5955  economy  zero       NAN              140
#
#         dep_time       arr_time     month     day
# 0        Evening          Night  February  Friday
# 1  Early Morning  Early Morning  February  Friday
# 2  Early Morning  Early Morning  February  Friday
# 3        Morning      Afternoon  February  Friday
# 4  Early Morning        Morning  February  Friday

# %%
df.stops.unique()
# Out:
# array(['zero', 'one', 'two_or_more'], dtype=object)

# %%
df['stops']=df['stops'].map({'zero':0, 'one':1, 'two_or_more':2}).astype(str)

# %%
df.stops =  df.stops.astype('int64')

# %%
df['class']=df['class'].map({'economy':0, 'business':1}).astype(int)

# %%
df.head()
# Out:
#     airline   from      to  price  class  stops stops_via  duration_in_min  \
# 0  SpiceJet  Delhi  Mumbai   5953      0      0       NAN              130
# 1  SpiceJet  Delhi  Mumbai   5953      0      0       NAN              140
# 2   AirAsia  Delhi  Mumbai   5956      0      0       NAN              130
# 3   Vistara  Delhi  Mumbai   5955      0      0       NAN              135
# 4   Vistara  Delhi  Mumbai   5955      0      0       NAN              140
#
#         dep_time       arr_time     month     day
# 0        Evening          Night  February  Friday
# 1  Early Morning  Early Morning  February  Friday
# 2  Early Morning  Early Morning  February  Friday
# 3        Morning      Afternoon  February  Friday
# 4  Early Morning        Morning  February  Friday

# %%
df.isna().sum()
# Out:
# airline            0
# from               0
# to                 0
# price              0
# class              0
# stops              0
# stops_via          0
# duration_in_min    0
# dep_time           0
# arr_time           0
# month              0
# day                0
# dtype: int64

# %%
df.drop(['stops_via'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     airline   from      to  price  class  stops  duration_in_min  \
# 0  SpiceJet  Delhi  Mumbai   5953      0      0              130
# 1  SpiceJet  Delhi  Mumbai   5953      0      0              140
# 2   AirAsia  Delhi  Mumbai   5956      0      0              130
# 3   Vistara  Delhi  Mumbai   5955      0      0              135
# 4   Vistara  Delhi  Mumbai   5955      0      0              140
#
#         dep_time       arr_time     month     day
# 0        Evening          Night  February  Friday
# 1  Early Morning  Early Morning  February  Friday
# 2  Early Morning  Early Morning  February  Friday
# 3        Morning      Afternoon  February  Friday
# 4  Early Morning        Morning  February  Friday

# %%
def week(w):
    if w == 'Saturday' or w == 'Sunday':
        weeks = 'Weekend'
    elif w == 'Monday' or w == 'Tuesday' or w == 'Wednesday' or w == 'Thursday' or w == 'Friday':
        weeks = 'Weekday'
    else:
        weeks = 'NaN'
        
    return weeks

# %%
df['weekend/weekdays'] = df['day'].apply(week)

# %%
df.head()
# Out:
#     airline   from      to  price  class  stops  duration_in_min  \
# 0  SpiceJet  Delhi  Mumbai   5953      0      0              130
# 1  SpiceJet  Delhi  Mumbai   5953      0      0              140
# 2   AirAsia  Delhi  Mumbai   5956      0      0              130
# 3   Vistara  Delhi  Mumbai   5955      0      0              135
# 4   Vistara  Delhi  Mumbai   5955      0      0              140
#
#         dep_time       arr_time     month     day weekend/weekdays
# 0        Evening          Night  February  Friday          Weekday
# 1  Early Morning  Early Morning  February  Friday          Weekday
# 2  Early Morning  Early Morning  February  Friday          Weekday
# 3        Morning      Afternoon  February  Friday          Weekday
# 4  Early Morning        Morning  February  Friday          Weekday
